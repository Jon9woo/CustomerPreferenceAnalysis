# %% [markdown]
# # 고객 취향분석
# ## User Data 분석

# %% [markdown]
# # 데이터 불러오기

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import datetime as dt
from sklearn.cluster import KMeans

# %%
# Load the data
path =  '../data'
data = pd.read_csv(f'{path}/2019-Oct_purchase_preprocessed.csv')
data.head()
# Out:
#                 event_time event_type  product_id          category_id  \
# 0  2019-10-01 00:02:14 UTC   purchase     1004856  2053013555631882655
# 1  2019-10-01 00:04:37 UTC   purchase     1002532  2053013555631882655
# 2  2019-10-01 00:07:07 UTC   purchase    13800054  2053013557418656265
# 3  2019-10-01 00:09:26 UTC   purchase     4804055  2053013554658804075
# 4  2019-10-01 00:09:54 UTC   purchase     4804056  2053013554658804075
#
#                  category_code    brand   price    user_id  \
# 0       electronics.smartphone  samsung  130.76  543272936
# 1       electronics.smartphone    apple  642.69  551377651
# 2    furniture.bathroom.toilet  santeri   54.42  555332717
# 3  electronics.audio.headphone    apple  189.91  524601178
# 4  electronics.audio.headphone    apple  161.98  551377651
#
#                            user_session        ctg_1       ctg_2      ctg_3  \
# 0  8187d148-3c41-46d4-b0c0-9c08cd9dc564  electronics  smartphone        NaN
# 1  3c80f0d6-e9ec-4181-8c5c-837a30be2d68  electronics  smartphone        NaN
# 2  1dea3ee2-2ded-42e8-8e7a-4e2ad6ae942f    furniture    bathroom     toilet
# 3  2af9b570-0942-4dcd-8f25-4d84fba82553  electronics       audio  headphone
# 4  3c80f0d6-e9ec-4181-8c5c-837a30be2d68  electronics       audio  headphone
#
#   ctg_4
# 0   NaN
# 1   NaN
# 2   NaN
# 3   NaN
# 4   NaN

# %%
# Out:
#                 event_time event_type  product_id          category_id  \
# 0  2019-10-01 00:02:14 UTC   purchase     1004856  2053013555631882655
# 1  2019-10-01 00:04:37 UTC   purchase     1002532  2053013555631882655
# 2  2019-10-01 00:07:07 UTC   purchase    13800054  2053013557418656265
# 3  2019-10-01 00:09:26 UTC   purchase     4804055  2053013554658804075
# 4  2019-10-01 00:09:54 UTC   purchase     4804056  2053013554658804075
#
#                  category_code    brand   price    user_id  \
# 0       electronics.smartphone  samsung  130.76  543272936
# 1       electronics.smartphone    apple  642.69  551377651
# 2    furniture.bathroom.toilet  santeri   54.42  555332717
# 3  electronics.audio.headphone    apple  189.91  524601178
# 4  electronics.audio.headphone    apple  161.98  551377651
#
#                            user_session        ctg_1       ctg_2      ctg_3  \
# 0  8187d148-3c41-46d4-b0c0-9c08cd9dc564  electronics  smartphone        NaN
# 1  3c80f0d6-e9ec-4181-8c5c-837a30be2d68  electronics  smartphone        NaN
# 2  1dea3ee2-2ded-42e8-8e7a-4e2ad6ae942f    furniture    bathroom     toilet
# 3  2af9b570-0942-4dcd-8f25-4d84fba82553  electronics       audio  headphone
# 4  3c80f0d6-e9ec-4181-8c5c-837a30be2d68  electronics       audio  headphone
#
#   ctg_4
# 0   NaN
# 1   NaN
# 2   NaN
# 3   NaN
# 4   NaN
